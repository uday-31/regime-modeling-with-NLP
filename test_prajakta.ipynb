# %% [markdown]
# Group Members: Dhruv, Rohan, Sarthak, Uday

# %%
# !pip install yahoofinance
# !pip install hmmlearn
# !pip install seaborn
# !pip install pandas==1.5.1
# !pip install numpy==1.21.4

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from datetime import datetime
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sys
import os
sys.path.append(os.getcwd() + '/modules')
import seaborn as sns

from modules.cross_validation import Pipeline, CustomCrossValidation
from modules.directional_change import *
from modules.hidden_markov_model import make_regime_plots
from modules.logistic_regression import do_all_LR
from modules.MixtureModels import *
from modules.NaiveBayesClassifier import *
from modules.svm import do_all_SVM
from modules.timeseries import *
from modules.trading_strategy import *
import matplotlib.patches as mpatches

import warnings
warnings.filterwarnings('ignore')

plt.style.use('seaborn')
sns.set_theme()

# %% [markdown]
# # Experiments

# %% [markdown]
# Put self-contained code here for different experiments run. Easier to put in the report that way.

# %%
fomc_data = pd.read_csv('./assets/fomc_documents.csv')

# %%
fomc_data.meeting_date = pd.to_datetime(fomc_data.meeting_date)
fomc_data = fomc_data[fomc_data.document_kind.isin(['historical_minutes', 'minutes', 'minutes_of_actions'])]
fomc_data['meeting_year'] = fomc_data.meeting_date.dt.year
fomc_data = fomc_data[fomc_data.meeting_year >= 1985]
# fomc_data.head()

# %%
def clean_text(text: str):
    text = text.lower()
    split_by = ''
    if 'the manager' in text and 'unanimous' in text:
        if text.index('the manager') > text.index('unanimous'):
            split_by = 'unanimous'
        else:
            split_by = 'the manager'
    elif 'the manager' in text:
        split_by = 'the manager'
    elif 'unanimous' in text:
        split_by = 'unanimous'
    else:
        raise ValueError('Neither in text!')

    return text.split(split_by)[1]

# %%
fomc_data.text = fomc_data.text.apply(clean_text)
fomc_data.head(1)
# Out:
#            document_kind meeting_date release_date  \
# 2947  minutes_of_actions   1985-02-13   1985-03-15
#
#                                                    text  \
# 2947   vote, e. gerald corrigan was elected to serve...
#
#                                                     url  meeting_year
# 2947  https://www.federalreserve.gov/monetarypolicy/...          1985

# %%
import nltk
from sklearn.feature_extraction.text import ENGLISH_STOP_WORDS

FOMC_STOP_WORDS = ["federal", "reserve", "board", "meeting", "committee", "minutes", "members"]
def custom_stop_words():
    stop_words = list(ENGLISH_STOP_WORDS) + FOMC_STOP_WORDS
    return stop_words

def join_tokens(tokens):
    return " ".join(tokens)


def remove_stop_words(tokens):
    stop_words = custom_stop_words()
    tokens = [word.lower() for word in tokens if word.isalpha()]
    result = [w.lower() for w in tokens if w.lower() not in stop_words]
    return result

# %%
def tokenize_data(df):
    df['tokens'] = df.text.apply(nltk.word_tokenize)
    df["tokens_wo_stop"] = df.tokens.apply(remove_stop_words)
    df["new_text"] = df.tokens_wo_stop.apply(join_tokens)
    return df

def manual_tf_idf(text: pd.Series):
    """
    This function manually computes the TF-IDF values for the given column of
    documents, in order to avoid the incorrect computations performed by
    sklearn's native implementation.

    @param text(pd.Series): the (n, 1) column of n documents for which TF-IDF
                            is being computed
    @returns tf_idf_df(np.ndarray): the (n, n_words) representing TF-IDF values
    """
    # Get number of documents
    n_docs = text.shape[0]
    from sklearn.feature_extraction.text import CountVectorizer
    # Generate bag-of-words matrix
    def_vectorizer = CountVectorizer(token_pattern='[a-zA-Z]+')
    word_bow_matrix = def_vectorizer.fit_transform(text)
    word_bow_df = pd.DataFrame(
        word_bow_matrix.toarray(),
        columns=def_vectorizer.get_feature_names_out()
    )

    # Create TF matrix
    tf_df = word_bow_df / word_bow_df.sum(axis=1).values.reshape(n_docs, 1)

    # Compute IDF values
    idf = np.log(n_docs / (word_bow_df / word_bow_df.values).sum(axis=0))

    # Manually create TF-IDF matrix
    tfidf_df = tf_df * idf

    return tfidf_df

# %%
fomc_data = tokenize_data(fomc_data)

# %%
# !pip install gensim# !pip install gensim
import gensim
gensim_statements = fomc_data["tokens_wo_stop"] .tolist()
from gensim.corpora import Dictionary
dict_gensim_statements = Dictionary(gensim_statements)
bow_gensim_statements = [dict_gensim_statements.doc2bow(d) for d in gensim_statements]

# %%
from gensim.models import TfidfModel
from gensim.models.nmf import Nmf
from gensim.models.coherencemodel import CoherenceModel

tfidf_model = TfidfModel(bow_gensim_statements)
tfidf_statements = tfidf_model[bow_gensim_statements]

# %%
dict_gensim_statements.num_docs
# Out:
# 309

# %%
from gensim.matutils import corpus2dense, corpus2csc
num_docs = dict_gensim_statements.num_docs
num_terms = len(dict_gensim_statements.keys())
corpus_tfidf_dense = corpus2dense(tfidf_statements, num_terms, num_docs)
corpus_tfidf_sparse = corpus2csc(tfidf_statements, num_terms, num_docs=num_docs)

# %%
from sklearn import preprocessing

# fomc_norm_dense = preprocessing.normalize(corpus_tfidf_dense)
# fomc_norm_sparse = preprocessing.normalize(corpus_tfidf_sparse)

# %%
from wordcloud import WordCloud

def wordcloud_clusters(model, vectors, features, n_top_words=50):
  num_clouds = len(np.unique(model.labels_))
  fig, axs = plt.subplots(num_clouds, 1, figsize=(6.4, 6.4 * num_clouds))
  axs = axs.flatten()

  for i, cluster in enumerate(np.unique(model.labels_)):
    ax = axs[i]
    size = {}
    words = vectors[model.labels_ == cluster].sum(axis=0)
    largest = words.argsort()[::-1]
    for j in range(0, n_top_words):
        size[features[largest[j]]] = abs(words[largest[j]])
    wc = WordCloud(
        background_color="white",
        max_words=100,
        width=500,
        height=300
    )
    wc.generate_from_frequencies(size)
    # plt.figure(figsize=(4, 4))
    ax.imshow(wc, interpolation="bilinear")
    ax.axis("off")
    ax.set_title(f'Cluster = {cluster}')

  fig.tight_layout()

# %%
from sklearn.cluster import KMeans

def fit_kmeans(corpus, dictionary, K=3, to_array=False):
    fomc_norm = preprocessing.normalize(corpus)
    if to_array:
        fomc_norm = fomc_norm.toarray()

    k_means_fomc = KMeans(n_clusters=K, random_state=42)
    k_means_fomc.fit(fomc_norm)
    sizes_df = pd.DataFrame.from_dict({
        'CLUSTER': [i for i in range(K)],
        'CLUSTER_SIZE': [np.sum(k_means_fomc.labels_ == i) for i in range(K)],
    }).set_index('CLUSTER')
    display(sizes_df)
    wordcloud_clusters(
    k_means_fomc,
    fomc_norm,
    dictionary
)
    return k_means_fomc

# %%
print("TFIDF-dense matrix with K = 2")
kmeans_cl = fit_kmeans(corpus_tfidf_dense.T, dict_gensim_statements, K=2)
# Out:
# TFIDF-dense matrix with K = 2
#          CLUSTER_SIZE
# CLUSTER
# 0                 204
# 1                 105

# %%
print("TFIDF-sparse matrix with K = 2")
fit_kmeans(corpus_tfidf_sparse.T, dict_gensim_statements, K=2, to_array=True)
# Out:
# TFIDF-sparse matrix with K = 3
#          CLUSTER_SIZE
# CLUSTER
# 0                 204
# 1                 105

# %%
tfidf_df = manual_tf_idf(fomc_data.new_text)
fit_kmeans(tfidf_df.values, tfidf_df.columns.tolist(), K=2)
# Out:
# c:\Users\prajp\Anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\prajp\Anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
#          CLUSTER_SIZE
# CLUSTER
# 0                 204
# 1                 105

# %%
cluster_labels = kmeans_cl.predict(preprocessing.normalize(corpus_tfidf_dense.T))

# %%
fomc_data["kmeans_labels"] = cluster_labels

# %%
fomc_data["kmeans_labels"].value_counts()
# Out:
# 0    204
# 1    105
# Name: kmeans_labels, dtype: int64

# %%
fomc_data["meeting_date"]
# Out:
# 2947   1985-02-13
# 2960   1985-03-26
# 2968   1985-05-21
# 2982   1985-07-10
# 2992   1985-08-20
#           ...
# 5933   2022-12-14
# 5936   2023-02-01
# 5940   2023-03-22
# 5946   2023-05-03
# 5953   2023-06-14
# Name: meeting_date, Length: 309, dtype: datetime64[ns]

# %%
full_date_range = pd.date_range(start=datetime(1985, 1, 1), end=fomc_data["meeting_date"].max())
label_data = pd.DataFrame().from_dict({"meeting_date":full_date_range})

# %%
label_data = pd.merge(label_data, fomc_data[["meeting_date", "kmeans_labels"]], on="meeting_date", how="left").fillna(method="bfill")

# %%
label_data["kmeans_labels"] = label_data["kmeans_labels"].astype("int")

# %%
label_data.to_csv("./assets/kmeans_labels.csv")

# %%
def train_nmf_coh(num_topics=5, cscore="c_v"):
    mod = Nmf(corpus=tfidf_statements, id2word=dict_gensim_statements, num_topics=num_topics)
    coh = CoherenceModel(mod, texts=gensim_statements, dictionary=dict_gensim_statements, coherence=cscore)
    return coh.get_coherence_per_topic()
print("2 C_V", train_nmf_coh(2))
print("5 C_V", train_nmf_coh(5))
print("2 u_mass", train_nmf_coh(2, "u_mass"))
print("5 u_mass", train_nmf_coh(5, "u_mass"))
# Out:
# 2 C_V [0.3314911984069063, 0.24938320261547467]
# 5 C_V [0.27683381059244894, 0.27684108389192874, 0.3411019004384309, 0.28532767289018734, 0.3917587761951209]
# 2 u_mass [-3.6123635383889856, -0.5928480464762796]
# 5 u_mass [-1.0516055510736921, -1.119229632822166, -0.7040752812678873, -0.3322174008361756, -0.5419348381197167]

# %% [markdown]
# # Pipeline With Cross-Validation

# %%
""" Grid for hyperparameter tuning """

parameter_grid = {
    'theta': np.arange(0.01, stop=0.021, step=0.005),
    'DC_indicator': ['R', 'TMV', 'T'],
    'epsilon': [0.6, 0.65, 0.7, 0.75, 0.8]
}

# %%
""" Pull data and run the grid search. We want to maximize profit. """

trading_day = {'equity':12, 'fx':12,'bond':12}
df_ts = get_data('^GSPC', start_date='2005-01-01', delta=trading_day['equity'])
cv = CustomCrossValidation(pipeline_class=Pipeline, parameter_grid=parameter_grid, verbose=True)
cv.fit(data = df_ts, metric='profit', minimize=False)
# Out:
# [*********************100%***********************]  1 of 1 completed
# Iteration: 1 of 45: Parameters: {'DC_indicator': 'R', 'epsilon': 0.6, 'theta': 0.01}
# Iteration: 1 of 45: Training complete.
# Iteration: 1 of 45: Loss: {'drawdown': 0.1305995614876654, 'profit': 0.11294466215834031, 'sharpe': 0.45221807530971014}
# Iteration: 2 of 45: Parameters: {'DC_indicator': 'R', 'epsilon': 0.6, 'theta': 0.015}
# Iteration: 2 of 45: Training complete.
# Iteration: 2 of 45: Loss: {'drawdown': 0.13110416467530533, 'profit': 0.09080363474279118, 'sharpe': 0.30836236577557885}
# Iteration: 3 of 45: Parameters: {'DC_indicator': 'R', 'epsilon': 0.6, 'theta': 0.019999999999999997}
# Iteration: 3 of 45: Training complete.
# Iteration: 3 of 45: Loss: {'drawdown': 0.14305879638395586, 'profit': 0.08665954285897826, 'sharpe': 0.2944372978219167}
# Iteration: 4 of 45: Parameters: {'DC_indicator': 'R', 'epsilon': 0.65, 'theta': 0.01}
# Iteration: 4 of 45: Training complete.
# Iteration: 4 of 45: Loss: {'drawdown': 0.09592641438381609, 'profit': 0.23005002789432405, 'sharpe': 0.6338382523468278}
# Iteration: 5 of 45: Parameters: {'DC_indicator': 'R', 'epsilon': 0.65, 'theta': 0.015}
# Iteration: 5 of 45: Training complete.
# Iteration: 5 of 45: Loss: {'drawdown': 0.10142322222070882, 'profit': 0.2383949768051974, 'sharpe': 0.5881741375622075}
# Iteration: 6 of 45: Parameters: {'DC_indicator': 'R', 'epsilon': 0.65, 'theta': 0.019999999999999997}
# Iteration: 6 of 45: Training complete.
# Iteration: 6 of 45: Loss: {'drawdown': 0.11502148614759142, 'profit': 0.18052846609422213, 'sharpe': 0.46410632614014946}
# Iteration: 7 of 45: Parameters: {'DC_indicator': 'R', 'epsilon': 0.7, 'theta': 0.01}
# Iteration: 7 of 45: Training complete.
# Iteration: 7 of 45: Loss: {'drawdown': 0.09592641438381601, 'profit': 0.29421365350328466, 'sharpe': 0.7511886035949097}
# Iteration: 8 of 45: Parameters: {'DC_indicator': 'R', 'epsilon': 0.7, 'theta': 0.015}
# Iteration: 8 of 45: Training complete.
# Iteration: 8 of 45: Loss: {'drawdown': 0.10142322222070861, 'profit': 0.2580500693512091, 'sharpe': 0.6227398480970567}
# Iteration: 9 of 45: Parameters: {'DC_indicator': 'R', 'epsilon': 0.7, 'theta': 0.019999999999999997}
# Iteration: 9 of 45: Training complete.
# Iteration: 9 of 45: Loss: {'drawdown': 0.11502148614759128, 'profit': 0.18641725732826964, 'sharpe': 0.4742170515820278}
# Iteration: 10 of 45: Parameters: {'DC_indicator': 'R', 'epsilon': 0.75, 'theta': 0.01}
# Iteration: 10 of 45: Training complete.
# Iteration: 10 of 45: Loss: {'drawdown': 0.08494409644887348, 'profit': 0.3053472712050658, 'sharpe': 0.753580228170561}
# Iteration: 11 of 45: Parameters: {'DC_indicator': 'R', 'epsilon': 0.75, 'theta': 0.015}
# Iteration: 11 of 45: Training complete.
# Iteration: 11 of 45: Loss: {'drawdown': 0.10142322222070874, 'profit': 0.2693321347050668, 'sharpe': 0.6308451131605969}
# Iteration: 12 of 45: Parameters: {'DC_indicator': 'R', 'epsilon': 0.75, 'theta': 0.019999999999999997}
# Iteration: 12 of 45: Training complete.
# Iteration: 12 of 45: Loss: {'drawdown': 0.1287001979117603, 'profit': 0.13613751414123088, 'sharpe': 0.38511479550473937}
# Iteration: 13 of 45: Parameters: {'DC_indicator': 'R', 'epsilon': 0.8, 'theta': 0.01}
# Iteration: 13 of 45: Training complete.
# Iteration: 13 of 45: Loss: {'drawdown': 0.08494409644887346, 'profit': 0.3578784282703851, 'sharpe': 0.8304325174124405}
# Iteration: 14 of 45: Parameters: {'DC_indicator': 'R', 'epsilon': 0.8, 'theta': 0.015}
# Iteration: 14 of 45: Training complete.
# Iteration: 14 of 45: Loss: {'drawdown': 0.10381441858206011, 'profit': 0.21295836963266002, 'sharpe': 0.5317189710801369}
# Iteration: 15 of 45: Parameters: {'DC_indicator': 'R', 'epsilon': 0.8, 'theta': 0.019999999999999997}
# Iteration: 15 of 45: Training complete.
# Iteration: 15 of 45: Loss: {'drawdown': 0.11869736346765723, 'profit': 0.1441147124526876, 'sharpe': 0.39921074420924096}
# Iteration: 16 of 45: Parameters: {'DC_indicator': 'TMV', 'epsilon': 0.6, 'theta': 0.01}
# Iteration: 16 of 45: Training complete.
# Iteration: 16 of 45: Loss: {'drawdown': 0.15476858537838412, 'profit': 0.05660923866428269, 'sharpe': 0.27909948638735205}
# Iteration: 17 of 45: Parameters: {'DC_indicator': 'TMV', 'epsilon': 0.6, 'theta': 0.015}
# Iteration: 17 of 45: Training complete.
# Iteration: 17 of 45: Loss: {'drawdown': 0.16062405648755845, 'profit': 0.0879903043994934, 'sharpe': 0.3511267874220865}
# Iteration: 18 of 45: Parameters: {'DC_indicator': 'TMV', 'epsilon': 0.6, 'theta': 0.019999999999999997}
# Iteration: 18 of 45: Training complete.
# Iteration: 18 of 45: Loss: {'drawdown': 0.17240205914205342, 'profit': 0.07111066491993512, 'sharpe': 0.28659436450957937}
# Iteration: 19 of 45: Parameters: {'DC_indicator': 'TMV', 'epsilon': 0.65, 'theta': 0.01}
# Iteration: 19 of 45: Training complete.
# Iteration: 19 of 45: Loss: {'drawdown': 0.15476858537838412, 'profit': 0.05660923866428269, 'sharpe': 0.27909948638735205}
# Iteration: 20 of 45: Parameters: {'DC_indicator': 'TMV', 'epsilon': 0.65, 'theta': 0.015}
# Iteration: 20 of 45: Training complete.
# Iteration: 20 of 45: Loss: {'drawdown': 0.16062405648755845, 'profit': 0.0879903043994934, 'sharpe': 0.3511267874220865}
# Iteration: 21 of 45: Parameters: {'DC_indicator': 'TMV', 'epsilon': 0.65, 'theta': 0.019999999999999997}
# Iteration: 21 of 45: Training complete.
# Iteration: 21 of 45: Loss: {'drawdown': 0.17240205914205342, 'profit': 0.07111066491993512, 'sharpe': 0.28659436450957937}
# Iteration: 22 of 45: Parameters: {'DC_indicator': 'TMV', 'epsilon': 0.7, 'theta': 0.01}
# Iteration: 22 of 45: Training complete.
# Iteration: 22 of 45: Loss: {'drawdown': 0.15476858537838412, 'profit': 0.05660923866428269, 'sharpe': 0.27909948638735205}
# Iteration: 23 of 45: Parameters: {'DC_indicator': 'TMV', 'epsilon': 0.7, 'theta': 0.015}
# Iteration: 23 of 45: Training complete.
# Iteration: 23 of 45: Loss: {'drawdown': 0.16062405648755845, 'profit': 0.0879903043994934, 'sharpe': 0.3511267874220865}
# Iteration: 24 of 45: Parameters: {'DC_indicator': 'TMV', 'epsilon': 0.7, 'theta': 0.019999999999999997}
# Iteration: 24 of 45: Training complete.
# Iteration: 24 of 45: Loss: {'drawdown': 0.17240205914205342, 'profit': 0.07111066491993512, 'sharpe': 0.28659436450957937}
# Iteration: 25 of 45: Parameters: {'DC_indicator': 'TMV', 'epsilon': 0.75, 'theta': 0.01}
# Iteration: 25 of 45: Training complete.
# Iteration: 25 of 45: Loss: {'drawdown': 0.15476858537838412, 'profit': 0.05660923866428269, 'sharpe': 0.27909948638735205}
# Iteration: 26 of 45: Parameters: {'DC_indicator': 'TMV', 'epsilon': 0.75, 'theta': 0.015}
# Iteration: 26 of 45: Training complete.
# Iteration: 26 of 45: Loss: {'drawdown': 0.16062405648755845, 'profit': 0.0879903043994934, 'sharpe': 0.3511267874220865}
# Iteration: 27 of 45: Parameters: {'DC_indicator': 'TMV', 'epsilon': 0.75, 'theta': 0.019999999999999997}
# Iteration: 27 of 45: Training complete.
# Iteration: 27 of 45: Loss: {'drawdown': 0.17240205914205342, 'profit': 0.07111066491993512, 'sharpe': 0.28659436450957937}
# Iteration: 28 of 45: Parameters: {'DC_indicator': 'TMV', 'epsilon': 0.8, 'theta': 0.01}
# Iteration: 28 of 45: Training complete.
# Iteration: 28 of 45: Loss: {'drawdown': 0.15476858537838412, 'profit': 0.05660923866428269, 'sharpe': 0.27909948638735205}
# Iteration: 29 of 45: Parameters: {'DC_indicator': 'TMV', 'epsilon': 0.8, 'theta': 0.015}
# Iteration: 29 of 45: Training complete.
# Iteration: 29 of 45: Loss: {'drawdown': 0.16062405648755845, 'profit': 0.0879903043994934, 'sharpe': 0.3511267874220865}
# Iteration: 30 of 45: Parameters: {'DC_indicator': 'TMV', 'epsilon': 0.8, 'theta': 0.019999999999999997}
# Iteration: 30 of 45: Training complete.
# Iteration: 30 of 45: Loss: {'drawdown': 0.17240205914205342, 'profit': 0.07111066491993512, 'sharpe': 0.28659436450957937}
# Iteration: 31 of 45: Parameters: {'DC_indicator': 'T', 'epsilon': 0.6, 'theta': 0.01}
# Iteration: 31 of 45: Training complete.
# Iteration: 31 of 45: Loss: {'drawdown': 0.14971796958846756, 'profit': 0.0806240234970681, 'sharpe': 0.29264327205742896}
# Iteration: 32 of 45: Parameters: {'DC_indicator': 'T', 'epsilon': 0.6, 'theta': 0.015}
# Iteration: 32 of 45: Training complete.
# Iteration: 32 of 45: Loss: {'drawdown': 0.151380569897623, 'profit': 0.20477916728119117, 'sharpe': 0.5091128647012347}
# Iteration: 33 of 45: Parameters: {'DC_indicator': 'T', 'epsilon': 0.6, 'theta': 0.019999999999999997}
# Iteration: 33 of 45: Training complete.
# Iteration: 33 of 45: Loss: {'drawdown': 0.173192787639177, 'profit': 0.21010499133694815, 'sharpe': 0.495565497339407}
# Iteration: 34 of 45: Parameters: {'DC_indicator': 'T', 'epsilon': 0.65, 'theta': 0.01}
# Iteration: 34 of 45: Training complete.
# Iteration: 34 of 45: Loss: {'drawdown': 0.14971796958846756, 'profit': 0.0806240234970681, 'sharpe': 0.29264327205742896}
# Iteration: 35 of 45: Parameters: {'DC_indicator': 'T', 'epsilon': 0.65, 'theta': 0.015}
# Iteration: 35 of 45: Training complete.
# Iteration: 35 of 45: Loss: {'drawdown': 0.151380569897623, 'profit': 0.20477916728119117, 'sharpe': 0.5091128647012347}
# Iteration: 36 of 45: Parameters: {'DC_indicator': 'T', 'epsilon': 0.65, 'theta': 0.019999999999999997}
# Iteration: 36 of 45: Training complete.
# Iteration: 36 of 45: Loss: {'drawdown': 0.173192787639177, 'profit': 0.21010499133694815, 'sharpe': 0.495565497339407}
# Iteration: 37 of 45: Parameters: {'DC_indicator': 'T', 'epsilon': 0.7, 'theta': 0.01}
# Iteration: 37 of 45: Training complete.
# Iteration: 37 of 45: Loss: {'drawdown': 0.14971796958846756, 'profit': 0.0806240234970681, 'sharpe': 0.29264327205742896}
# Iteration: 38 of 45: Parameters: {'DC_indicator': 'T', 'epsilon': 0.7, 'theta': 0.015}
# Iteration: 38 of 45: Training complete.
# Iteration: 38 of 45: Loss: {'drawdown': 0.151380569897623, 'profit': 0.20477916728119117, 'sharpe': 0.5091128647012347}
# Iteration: 39 of 45: Parameters: {'DC_indicator': 'T', 'epsilon': 0.7, 'theta': 0.019999999999999997}
# Iteration: 39 of 45: Training complete.
# Iteration: 39 of 45: Loss: {'drawdown': 0.1731927876391769, 'profit': 0.18797419995285325, 'sharpe': 0.4602792463338078}
# Iteration: 40 of 45: Parameters: {'DC_indicator': 'T', 'epsilon': 0.75, 'theta': 0.01}
# Iteration: 40 of 45: Training complete.
# Iteration: 40 of 45: Loss: {'drawdown': 0.14971796958846756, 'profit': 0.0806240234970681, 'sharpe': 0.29264327205742896}
# Iteration: 41 of 45: Parameters: {'DC_indicator': 'T', 'epsilon': 0.75, 'theta': 0.015}
# Iteration: 41 of 45: Training complete.
# Iteration: 41 of 45: Loss: {'drawdown': 0.151380569897623, 'profit': 0.20477916728119117, 'sharpe': 0.5091128647012347}
# Iteration: 42 of 45: Parameters: {'DC_indicator': 'T', 'epsilon': 0.75, 'theta': 0.019999999999999997}
# Iteration: 42 of 45: Training complete.
# Iteration: 42 of 45: Loss: {'drawdown': 0.1731927876391769, 'profit': 0.18797419995285325, 'sharpe': 0.4602792463338078}
# Iteration: 43 of 45: Parameters: {'DC_indicator': 'T', 'epsilon': 0.8, 'theta': 0.01}
# Iteration: 43 of 45: Training complete.
# Iteration: 43 of 45: Loss: {'drawdown': 0.14971796958846756, 'profit': 0.0806240234970681, 'sharpe': 0.29264327205742896}
# Iteration: 44 of 45: Parameters: {'DC_indicator': 'T', 'epsilon': 0.8, 'theta': 0.015}
# Iteration: 44 of 45: Training complete.
# Iteration: 44 of 45: Loss: {'drawdown': 0.151380569897623, 'profit': 0.20477916728119117, 'sharpe': 0.5091128647012347}
# Iteration: 45 of 45: Parameters: {'DC_indicator': 'T', 'epsilon': 0.8, 'theta': 0.019999999999999997}
# Iteration: 45 of 45: Training complete.
# Iteration: 45 of 45: Loss: {'drawdown': 0.1731927876391769, 'profit': 0.18797419995285325, 'sharpe': 0.4602792463338078}

# %%
""" Optimal parameters and optimal value of the loss function. """

cv.get_optimal_loss()
# Out:
# {'drawdown': 0.08494409644887346,
#  'profit': 0.3578784282703851,
#  'sharpe': 0.8304325174124405,
#  'parameters': {'DC_indicator': 'R', 'epsilon': 0.8, 'theta': 0.01}}

# %%
""" Fit the model with the optimal parameters found. """

regime_trade = Pipeline(df_ts= df_ts, **cv.get_optimal_parameters())
regime_trade.fit(verbose = True)
# Out:
# Total duration of time: 407764800.0
# Total duration spent in Regime 0: 162172800.0
# Proportion of time spent in Regime 0: 0.3977116219938553
# Flipping labels between regimes.

# %%
""" Confirm that the trading metrics match. """
regime_trade.trading_metrics
# Out:
# {'drawdown': 0.08494409644887346,
#  'profit': 0.3578784282703851,
#  'sharpe': 0.8304325174124405}

# %%
""" Fit the same model for the control trading strategy."""

control = Pipeline(df_ts= df_ts, strat='control', **cv.get_optimal_parameters())
control.fit(plot=False, verbose = True)
# Out:
# Total duration of time: 407764800.0
# Total duration spent in Regime 0: 162172800.0
# Proportion of time spent in Regime 0: 0.3977116219938553
# Flipping labels between regimes.

# %%
""" Confirm that there is an improvement when we use the regimes. """

control.trading_metrics
# Out:
# {'drawdown': 0.10658049858278516,
#  'profit': 0.13305612063278272,
#  'sharpe': 0.3877989114498797}

# %%
""" If you want to look at all the grid search results. """
# sorted(cv.get_losses(), key=lambda d: d['profit'])
# Out:
# ' If you want to look at all the grid search results. '

# %%
""" Run the control strategy on test data. """
strat_test = Pipeline(df_ts= df_ts, to_test = True, strat='control', **cv.get_optimal_parameters())
strat_test.fit(verbose = True)
strat_test.trading_metrics_test
# Out:
# Total duration of time: 407764800.0
# Total duration spent in Regime 0: 162172800.0
# Proportion of time spent in Regime 0: 0.3977116219938553
# Flipping labels between regimes.
# {'drawdown': 0.1543405840247128,
#  'profit': 0.37101175204318526,
#  'sharpe': 0.47998209967808686}

# %%
""" Run the control2 strategy on test data. """
strat_test = Pipeline(df_ts= df_ts, to_test = True, strat='control2', **cv.get_optimal_parameters())
strat_test.fit(verbose = True)
strat_test.trading_metrics_test
# Out:
# Total duration of time: 407764800.0
# Total duration spent in Regime 0: 162172800.0
# Proportion of time spent in Regime 0: 0.3977116219938553
# Flipping labels between regimes.
# {'drawdown': 0.15456424726434365,
#  'profit': 0.3541043469635792,
#  'sharpe': 0.5213167068175325}

# %%
""" Run the strategy on test data. """
strat_test = Pipeline(df_ts= df_ts, to_test = True, **cv.get_optimal_parameters())
strat_test.fit(verbose = True)
strat_test.trading_metrics_test
# Out:
# Total duration of time: 407764800.0
# Total duration spent in Regime 0: 162172800.0
# Proportion of time spent in Regime 0: 0.3977116219938553
# Flipping labels between regimes.
# {'drawdown': 0.25057140523989796,
#  'profit': 1.0823749162355516,
#  'sharpe': 1.210407488924396}

# %%
""" If you want to get the results in Latex """
# print(cv.get_results_in_latex('Naive Bayes Cross-Validation Results'))
# Out:
# ' If you want to get the results in Latex '

# %%
""" Plot our predicted regimes on the test set. """

regimes = strat_test.regimes_test

fig, ax = plt.subplots(figsize=(12,6))
df_ts["2020-01-01":].plot(ax=ax, color='black')
clr = {0:'grey',1:'red',2:'green'}

# assume default before we see any change
ax.axvspan('2020-01-01',regimes.index[0], alpha=1, color=clr[regimes[0]])

# look at regimes
for time_start, time_end, regime in zip(regimes.index[:-1], regimes.index[1:], regimes.values[:-1]):
    ax.axvspan(time_start,time_end, alpha=1, color=clr[regime])

# propagate last seen regime
ax.axvspan(time_end,"2022-12-31", alpha=1, color=clr[regimes[-1]])

ax.set_title(f"Regimes for S&P 500 on the test set")
ax.set_ylabel("Price")
plt.show()

# %%
""" Plot our predicted regimes on the validation set. """

regimes = strat_test.regimes_valid

fig, ax = plt.subplots(figsize=(12,6))
df_ts["2018-01-01":"2019-12-31"].plot(ax=ax, color='black')
clr = {0:'grey',1:'red'}

# assume default before we see any change
ax.axvspan('2018-01-01',regimes.index[0], alpha=1, color=clr[regimes[0]])

# look at the regimes
for time_start, time_end, regime in zip(regimes.index[:-1], regimes.index[1:], regimes.values[:-1]):
    ax.axvspan(time_start,time_end, alpha=1, color=clr[regime])

# propagate last seen regime
ax.axvspan(time_end,"2019-12-31", alpha=1, color=clr[regimes[-1]])

ax.set_title(f"Regimes for S&P 500 on the validation set")
ax.set_ylabel("Price")
plt.show()

# %% [markdown]
# ## Visualizing DC indicators

# %%
model = Pipeline(df_ts= df_ts, **cv.get_optimal_parameters())
model.fit()

# %%
# example
sample_ts = df_ts[1050:1085]
first_date = sample_ts.index[0]
last_date = sample_ts.index[-1]

dcc = []
dcc_idx = []
ext = []
ext_idx = []

for i in range(len(model.dc['train'])):
    dcc.append(model.dc['train'][i][1])
    dcc_idx.append(model.dc['train'][i][0])
    ext.append( model.dc['train'][i][3] )
    ext_idx.append( model.dc['train'][i][2] )

dcc = pd.Series( data=dcc, index = dcc_idx)
ext = pd.Series( data=ext, index = ext_idx)

sample_dcc = dcc.loc[first_date:last_date]#.index
sample_ext = ext.loc[first_date:last_date]#.index

fig,ax = plt.subplots(figsize=(16,8))
features = model.dc['train']
sns.lineplot(data=sample_ts, linewidth=3)
sns.scatterplot(x = sample_dcc.index, y = sample_dcc, color='black', s=150, label='DCC',alpha=1, ax=ax)
sns.scatterplot(x = sample_ext.index, y = sample_ext, color='red', s=150, label='EXT',alpha=0.6, ax=ax)

annotate_plot(ax, sample_ext, sample_dcc)

ax.set_title(f"DC indicators for S&P 500 with ϴ = {model.theta}")
ax.set_ylabel("Price")
ax.set_ylim([1390, 1500])
ax.legend()
plt.show()

# %% [markdown]
# ## Regime Characteristic Plots

# %%
model = Pipeline(df_ts= df_ts, to_test = True, **cv.get_optimal_parameters())
model.fit()
regimes_test = strat_test.regimes_test
regimes_valid = strat_test.regimes_valid

# %%
make_regime_plots(regimes_valid, model.tmv['valid'], model.T['valid'], 'S&P 500', 'validation')

# %%
make_regime_plots(regimes_test, model.tmv['test'], model.T['test'], 'S&P 500', 'test')

# %% [markdown]
# ## Comparing to Logistic Regression

# %%
""" Grid for hyperparameter tuning """

parameter_grid = {
    'theta': np.arange(0.01, stop=0.021, step=0.005),
    'DC_indicator': ['R', 'TMV', 'T'],
    'epsilon': [0.6, 0.65, 0.7, 0.75, 0.8],
    'model':['logistic_regression']
}

# %%
""" Pull data and run the grid search. We want to maximize profit. """

trading_day = {'equity':12, 'fx':12,'bond':9}
df_ts = get_data('^GSPC', start_date='2005-01-01', delta=trading_day['equity'])
cv2 = CustomCrossValidation(pipeline_class=Pipeline, parameter_grid=parameter_grid, verbose=True)
cv2.fit(data = df_ts, metric='profit', minimize=False)
# Out:
# [*********************100%***********************]  1 of 1 completed
# Iteration: 1 of 45: Parameters: {'DC_indicator': 'R', 'epsilon': 0.6, 'model': 'logistic_regression', 'theta': 0.01}
# Iteration: 1 of 45: Training complete.
# Iteration: 1 of 45: Loss: {'drawdown': 0.15476858537838412, 'profit': 0.05660923866428269, 'sharpe': 0.27909948638735205}
# Iteration: 2 of 45: Parameters: {'DC_indicator': 'R', 'epsilon': 0.6, 'model': 'logistic_regression', 'theta': 0.015}
# Iteration: 2 of 45: Training complete.
# Iteration: 2 of 45: Loss: {'drawdown': 0.16062405648755845, 'profit': 0.0879903043994934, 'sharpe': 0.3511267874220865}
# Iteration: 3 of 45: Parameters: {'DC_indicator': 'R', 'epsilon': 0.6, 'model': 'logistic_regression', 'theta': 0.019999999999999997}
# Iteration: 3 of 45: Training complete.
# Iteration: 3 of 45: Loss: {'drawdown': 0.17240205914205342, 'profit': 0.07111066491993512, 'sharpe': 0.28659436450957937}
# Iteration: 4 of 45: Parameters: {'DC_indicator': 'R', 'epsilon': 0.65, 'model': 'logistic_regression', 'theta': 0.01}
# Iteration: 4 of 45: Training complete.
# Iteration: 4 of 45: Loss: {'drawdown': 0.15476858537838412, 'profit': 0.05660923866428269, 'sharpe': 0.27909948638735205}
# Iteration: 5 of 45: Parameters: {'DC_indicator': 'R', 'epsilon': 0.65, 'model': 'logistic_regression', 'theta': 0.015}
# Iteration: 5 of 45: Training complete.
# Iteration: 5 of 45: Loss: {'drawdown': 0.16062405648755845, 'profit': 0.0879903043994934, 'sharpe': 0.3511267874220865}
# Iteration: 6 of 45: Parameters: {'DC_indicator': 'R', 'epsilon': 0.65, 'model': 'logistic_regression', 'theta': 0.019999999999999997}
# Iteration: 6 of 45: Training complete.
# Iteration: 6 of 45: Loss: {'drawdown': 0.17240205914205342, 'profit': 0.07111066491993512, 'sharpe': 0.28659436450957937}
# Iteration: 7 of 45: Parameters: {'DC_indicator': 'R', 'epsilon': 0.7, 'model': 'logistic_regression', 'theta': 0.01}
# Iteration: 7 of 45: Training complete.
# Iteration: 7 of 45: Loss: {'drawdown': 0.15476858537838412, 'profit': 0.05660923866428269, 'sharpe': 0.27909948638735205}
# Iteration: 8 of 45: Parameters: {'DC_indicator': 'R', 'epsilon': 0.7, 'model': 'logistic_regression', 'theta': 0.015}
# Iteration: 8 of 45: Training complete.
# Iteration: 8 of 45: Loss: {'drawdown': 0.16062405648755845, 'profit': 0.0879903043994934, 'sharpe': 0.3511267874220865}
# Iteration: 9 of 45: Parameters: {'DC_indicator': 'R', 'epsilon': 0.7, 'model': 'logistic_regression', 'theta': 0.019999999999999997}
# Iteration: 9 of 45: Training complete.
# Iteration: 9 of 45: Loss: {'drawdown': 0.17240205914205342, 'profit': 0.07111066491993512, 'sharpe': 0.28659436450957937}
# Iteration: 10 of 45: Parameters: {'DC_indicator': 'R', 'epsilon': 0.75, 'model': 'logistic_regression', 'theta': 0.01}
# Iteration: 10 of 45: Training complete.
# Iteration: 10 of 45: Loss: {'drawdown': 0.15476858537838412, 'profit': 0.05660923866428269, 'sharpe': 0.27909948638735205}
# Iteration: 11 of 45: Parameters: {'DC_indicator': 'R', 'epsilon': 0.75, 'model': 'logistic_regression', 'theta': 0.015}
# Iteration: 11 of 45: Training complete.
# Iteration: 11 of 45: Loss: {'drawdown': 0.16062405648755845, 'profit': 0.0879903043994934, 'sharpe': 0.3511267874220865}
# Iteration: 12 of 45: Parameters: {'DC_indicator': 'R', 'epsilon': 0.75, 'model': 'logistic_regression', 'theta': 0.019999999999999997}
# Iteration: 12 of 45: Training complete.
# Iteration: 12 of 45: Loss: {'drawdown': 0.17240205914205342, 'profit': 0.07111066491993512, 'sharpe': 0.28659436450957937}
# Iteration: 13 of 45: Parameters: {'DC_indicator': 'R', 'epsilon': 0.8, 'model': 'logistic_regression', 'theta': 0.01}
# Iteration: 13 of 45: Training complete.
# Iteration: 13 of 45: Loss: {'drawdown': 0.15476858537838412, 'profit': 0.05660923866428269, 'sharpe': 0.27909948638735205}
# Iteration: 14 of 45: Parameters: {'DC_indicator': 'R', 'epsilon': 0.8, 'model': 'logistic_regression', 'theta': 0.015}
# Iteration: 14 of 45: Training complete.
# Iteration: 14 of 45: Loss: {'drawdown': 0.16062405648755845, 'profit': 0.0879903043994934, 'sharpe': 0.3511267874220865}
# Iteration: 15 of 45: Parameters: {'DC_indicator': 'R', 'epsilon': 0.8, 'model': 'logistic_regression', 'theta': 0.019999999999999997}
# Iteration: 15 of 45: Training complete.
# Iteration: 15 of 45: Loss: {'drawdown': 0.17240205914205342, 'profit': 0.07111066491993512, 'sharpe': 0.28659436450957937}
# Iteration: 16 of 45: Parameters: {'DC_indicator': 'TMV', 'epsilon': 0.6, 'model': 'logistic_regression', 'theta': 0.01}
# Iteration: 16 of 45: Training complete.
# Iteration: 16 of 45: Loss: {'drawdown': 0.15476858537838412, 'profit': 0.05660923866428269, 'sharpe': 0.27909948638735205}
# Iteration: 17 of 45: Parameters: {'DC_indicator': 'TMV', 'epsilon': 0.6, 'model': 'logistic_regression', 'theta': 0.015}
# Iteration: 17 of 45: Training complete.
# Iteration: 17 of 45: Loss: {'drawdown': 0.16062405648755845, 'profit': 0.0879903043994934, 'sharpe': 0.3511267874220865}
# Iteration: 18 of 45: Parameters: {'DC_indicator': 'TMV', 'epsilon': 0.6, 'model': 'logistic_regression', 'theta': 0.019999999999999997}
# Iteration: 18 of 45: Training complete.
# Iteration: 18 of 45: Loss: {'drawdown': 0.17240205914205342, 'profit': 0.07111066491993512, 'sharpe': 0.28659436450957937}
# Iteration: 19 of 45: Parameters: {'DC_indicator': 'TMV', 'epsilon': 0.65, 'model': 'logistic_regression', 'theta': 0.01}
# Iteration: 19 of 45: Training complete.
# Iteration: 19 of 45: Loss: {'drawdown': 0.15476858537838412, 'profit': 0.05660923866428269, 'sharpe': 0.27909948638735205}
# Iteration: 20 of 45: Parameters: {'DC_indicator': 'TMV', 'epsilon': 0.65, 'model': 'logistic_regression', 'theta': 0.015}
# Iteration: 20 of 45: Training complete.
# Iteration: 20 of 45: Loss: {'drawdown': 0.16062405648755845, 'profit': 0.0879903043994934, 'sharpe': 0.3511267874220865}
# Iteration: 21 of 45: Parameters: {'DC_indicator': 'TMV', 'epsilon': 0.65, 'model': 'logistic_regression', 'theta': 0.019999999999999997}
# Iteration: 21 of 45: Training complete.
# Iteration: 21 of 45: Loss: {'drawdown': 0.17240205914205342, 'profit': 0.07111066491993512, 'sharpe': 0.28659436450957937}
# Iteration: 22 of 45: Parameters: {'DC_indicator': 'TMV', 'epsilon': 0.7, 'model': 'logistic_regression', 'theta': 0.01}
# Iteration: 22 of 45: Training complete.
# Iteration: 22 of 45: Loss: {'drawdown': 0.15476858537838412, 'profit': 0.05660923866428269, 'sharpe': 0.27909948638735205}
# Iteration: 23 of 45: Parameters: {'DC_indicator': 'TMV', 'epsilon': 0.7, 'model': 'logistic_regression', 'theta': 0.015}
# Iteration: 23 of 45: Training complete.
# Iteration: 23 of 45: Loss: {'drawdown': 0.16062405648755845, 'profit': 0.0879903043994934, 'sharpe': 0.3511267874220865}
# Iteration: 24 of 45: Parameters: {'DC_indicator': 'TMV', 'epsilon': 0.7, 'model': 'logistic_regression', 'theta': 0.019999999999999997}
# Iteration: 24 of 45: Training complete.
# Iteration: 24 of 45: Loss: {'drawdown': 0.17240205914205342, 'profit': 0.07111066491993512, 'sharpe': 0.28659436450957937}
# Iteration: 25 of 45: Parameters: {'DC_indicator': 'TMV', 'epsilon': 0.75, 'model': 'logistic_regression', 'theta': 0.01}
# Iteration: 25 of 45: Training complete.
# Iteration: 25 of 45: Loss: {'drawdown': 0.15476858537838412, 'profit': 0.05660923866428269, 'sharpe': 0.27909948638735205}
# Iteration: 26 of 45: Parameters: {'DC_indicator': 'TMV', 'epsilon': 0.75, 'model': 'logistic_regression', 'theta': 0.015}
# Iteration: 26 of 45: Training complete.
# Iteration: 26 of 45: Loss: {'drawdown': 0.16062405648755845, 'profit': 0.0879903043994934, 'sharpe': 0.3511267874220865}
# Iteration: 27 of 45: Parameters: {'DC_indicator': 'TMV', 'epsilon': 0.75, 'model': 'logistic_regression', 'theta': 0.019999999999999997}
# Iteration: 27 of 45: Training complete.
# Iteration: 27 of 45: Loss: {'drawdown': 0.17240205914205342, 'profit': 0.07111066491993512, 'sharpe': 0.28659436450957937}
# Iteration: 28 of 45: Parameters: {'DC_indicator': 'TMV', 'epsilon': 0.8, 'model': 'logistic_regression', 'theta': 0.01}
# Iteration: 28 of 45: Training complete.
# Iteration: 28 of 45: Loss: {'drawdown': 0.15476858537838412, 'profit': 0.05660923866428269, 'sharpe': 0.27909948638735205}
# Iteration: 29 of 45: Parameters: {'DC_indicator': 'TMV', 'epsilon': 0.8, 'model': 'logistic_regression', 'theta': 0.015}
# Iteration: 29 of 45: Training complete.
# Iteration: 29 of 45: Loss: {'drawdown': 0.16062405648755845, 'profit': 0.0879903043994934, 'sharpe': 0.3511267874220865}
# Iteration: 30 of 45: Parameters: {'DC_indicator': 'TMV', 'epsilon': 0.8, 'model': 'logistic_regression', 'theta': 0.019999999999999997}
# Iteration: 30 of 45: Training complete.
# Iteration: 30 of 45: Loss: {'drawdown': 0.17240205914205342, 'profit': 0.07111066491993512, 'sharpe': 0.28659436450957937}
# Iteration: 31 of 45: Parameters: {'DC_indicator': 'T', 'epsilon': 0.6, 'model': 'logistic_regression', 'theta': 0.01}
# Iteration: 31 of 45: Training complete.
# Iteration: 31 of 45: Loss: {'drawdown': 0.14971796958846756, 'profit': 0.0806240234970681, 'sharpe': 0.29264327205742896}
# Iteration: 32 of 45: Parameters: {'DC_indicator': 'T', 'epsilon': 0.6, 'model': 'logistic_regression', 'theta': 0.015}
# Iteration: 32 of 45: Training complete.
# Iteration: 32 of 45: Loss: {'drawdown': 0.1513805698976234, 'profit': 0.2077269652686724, 'sharpe': 0.5484074729823524}
# Iteration: 33 of 45: Parameters: {'DC_indicator': 'T', 'epsilon': 0.6, 'model': 'logistic_regression', 'theta': 0.019999999999999997}
# Iteration: 33 of 45: Training complete.
# Iteration: 33 of 45: Loss: {'drawdown': 0.173192787639177, 'profit': 0.21010499133694815, 'sharpe': 0.495565497339407}
# Iteration: 34 of 45: Parameters: {'DC_indicator': 'T', 'epsilon': 0.65, 'model': 'logistic_regression', 'theta': 0.01}
# Iteration: 34 of 45: Training complete.
# Iteration: 34 of 45: Loss: {'drawdown': 0.14971796958846756, 'profit': 0.0806240234970681, 'sharpe': 0.29264327205742896}
# Iteration: 35 of 45: Parameters: {'DC_indicator': 'T', 'epsilon': 0.65, 'model': 'logistic_regression', 'theta': 0.015}
# Iteration: 35 of 45: Training complete.
# Iteration: 35 of 45: Loss: {'drawdown': 0.1513805698976234, 'profit': 0.2077269652686724, 'sharpe': 0.5484074729823524}
# Iteration: 36 of 45: Parameters: {'DC_indicator': 'T', 'epsilon': 0.65, 'model': 'logistic_regression', 'theta': 0.019999999999999997}
# Iteration: 36 of 45: Training complete.
# Iteration: 36 of 45: Loss: {'drawdown': 0.1731927876391769, 'profit': 0.18797419995285325, 'sharpe': 0.4602792463338078}
# Iteration: 37 of 45: Parameters: {'DC_indicator': 'T', 'epsilon': 0.7, 'model': 'logistic_regression', 'theta': 0.01}
# Iteration: 37 of 45: Training complete.
# Iteration: 37 of 45: Loss: {'drawdown': 0.14971796958846756, 'profit': 0.0806240234970681, 'sharpe': 0.29264327205742896}
# Iteration: 38 of 45: Parameters: {'DC_indicator': 'T', 'epsilon': 0.7, 'model': 'logistic_regression', 'theta': 0.015}
# Iteration: 38 of 45: Training complete.
# Iteration: 38 of 45: Loss: {'drawdown': 0.1513805698976234, 'profit': 0.2077269652686724, 'sharpe': 0.5484074729823524}
# Iteration: 39 of 45: Parameters: {'DC_indicator': 'T', 'epsilon': 0.7, 'model': 'logistic_regression', 'theta': 0.019999999999999997}
# Iteration: 39 of 45: Training complete.
# Iteration: 39 of 45: Loss: {'drawdown': 0.1731927876391769, 'profit': 0.18797419995285325, 'sharpe': 0.4602792463338078}
# Iteration: 40 of 45: Parameters: {'DC_indicator': 'T', 'epsilon': 0.75, 'model': 'logistic_regression', 'theta': 0.01}
# Iteration: 40 of 45: Training complete.
# Iteration: 40 of 45: Loss: {'drawdown': 0.14971796958846756, 'profit': 0.0806240234970681, 'sharpe': 0.29264327205742896}
# Iteration: 41 of 45: Parameters: {'DC_indicator': 'T', 'epsilon': 0.75, 'model': 'logistic_regression', 'theta': 0.015}
# Iteration: 41 of 45: Training complete.
# Iteration: 41 of 45: Loss: {'drawdown': 0.1513805698976234, 'profit': 0.2077269652686724, 'sharpe': 0.5484074729823524}
# Iteration: 42 of 45: Parameters: {'DC_indicator': 'T', 'epsilon': 0.75, 'model': 'logistic_regression', 'theta': 0.019999999999999997}
# Iteration: 42 of 45: Training complete.
# Iteration: 42 of 45: Loss: {'drawdown': 0.17319278763917664, 'profit': 0.10536910824312051, 'sharpe': 0.324324735625209}
# Iteration: 43 of 45: Parameters: {'DC_indicator': 'T', 'epsilon': 0.8, 'model': 'logistic_regression', 'theta': 0.01}
# Iteration: 43 of 45: Training complete.
# Iteration: 43 of 45: Loss: {'drawdown': 0.14971796958846756, 'profit': 0.0806240234970681, 'sharpe': 0.29264327205742896}
# Iteration: 44 of 45: Parameters: {'DC_indicator': 'T', 'epsilon': 0.8, 'model': 'logistic_regression', 'theta': 0.015}
# Iteration: 44 of 45: Training complete.
# Iteration: 44 of 45: Loss: {'drawdown': 0.151380569897623, 'profit': 0.20477916728119117, 'sharpe': 0.5091128647012347}
# Iteration: 45 of 45: Parameters: {'DC_indicator': 'T', 'epsilon': 0.8, 'model': 'logistic_regression', 'theta': 0.019999999999999997}
# Iteration: 45 of 45: Training complete.
# Iteration: 45 of 45: Loss: {'drawdown': 0.17319278763917664, 'profit': 0.10536910824312051, 'sharpe': 0.324324735625209}

# %%
""" Optimal parameters and optimal value of the loss function. """

cv2.get_optimal_loss()
# Out:
# {'drawdown': 0.173192787639177,
#  'profit': 0.21010499133694815,
#  'sharpe': 0.495565497339407,
#  'parameters': {'DC_indicator': 'T',
#   'epsilon': 0.6,
#   'model': 'logistic_regression',
#   'theta': 0.019999999999999997}}

# %%
""" Fit the model with the optimal parameters found. """

regime_trade = Pipeline(df_ts= df_ts, **cv2.get_optimal_parameters())
regime_trade.fit(verbose = True)
# Out:
# Total duration of time: 396662400.0
# Total duration spent in Regime 1: 319291200.0
# Proportion of time spent in Regime 1: 0.8049444565454149
# Flipping labels between regimes.

# %%
""" Confirm that the trading metrics match. """
regime_trade.trading_metrics
# Out:
# {'drawdown': 0.173192787639177,
#  'profit': 0.21010499133694815,
#  'sharpe': 0.495565497339407}

# %%
""" Fit the same model for the control trading strategy."""

control = Pipeline(df_ts= df_ts, strat='control', **cv2.get_optimal_parameters())
control.fit(plot=False, verbose = True)
# Out:
# Total duration of time: 396662400.0
# Total duration spent in Regime 1: 319291200.0
# Proportion of time spent in Regime 1: 0.8049444565454149
# Flipping labels between regimes.

# %%
""" Confirm that there is an improvement when we use the regimes. """

control.trading_metrics
# Out:
# {'drawdown': 0.197107948275105,
#  'profit': 0.05202371492608826,
#  'sharpe': 0.23050795640032237}

# %%
""" Run the control strategy on test data. """
strat_test = Pipeline(df_ts= df_ts, to_test = True, strat='control', **cv2.get_optimal_parameters())
strat_test.fit(verbose = True)
strat_test.trading_metrics_test
# Out:
# Total duration of time: 396662400.0
# Total duration spent in Regime 1: 319291200.0
# Proportion of time spent in Regime 1: 0.8049444565454149
# Flipping labels between regimes.
# {'drawdown': 0.2701506503824544,
#  'profit': 0.40691312858269235,
#  'sharpe': 0.46022959091991317}

# %%
""" Run the control2 strategy on test data. """
strat_test = Pipeline(df_ts= df_ts, to_test = True, strat='control2', **cv2.get_optimal_parameters())
strat_test.fit(verbose = True)
strat_test.trading_metrics_test
# Out:
# Total duration of time: 396662400.0
# Total duration spent in Regime 1: 319291200.0
# Proportion of time spent in Regime 1: 0.8049444565454149
# Flipping labels between regimes.
# {'drawdown': 0.25873230856297735,
#  'profit': 0.5019380257164072,
#  'sharpe': 0.6115277904174444}

# %%
""" Run the strategy on test data. """
strat_test = Pipeline(df_ts= df_ts, to_test = True, **cv2.get_optimal_parameters())
strat_test.fit(verbose = True)
strat_test.trading_metrics_test
# Out:
# Total duration of time: 396662400.0
# Total duration spent in Regime 1: 319291200.0
# Proportion of time spent in Regime 1: 0.8049444565454149
# Flipping labels between regimes.
# {'drawdown': 0.21378587832646642,
#  'profit': 0.7527669340261292,
#  'sharpe': 0.752857105770566}

# %%
""" If you want to get the results in Latex """
# print(cv2.get_results_in_latex(
#     loss_columns=['profit', 'drawdown', 'sharpe'],
#     parameter_columns=['theta', 'epsilon', 'DC_indicator'],
#     caption='Logistic Regression Cross-Validation Results'))
# Out:
# ' If you want to get the results in Latex '

# %%
""" Plot our predicted regimes on the test set. """

regimes = strat_test.regimes_test

fig, ax = plt.subplots(figsize=(16,8))
df_ts["2020-01-01":].plot(ax=ax, color='black')
clr = {0:'grey',1:'red',2:'green'}

# assume default before we see any change
ax.axvspan('2020-01-01',regimes.index[0], alpha=1, color=clr[regimes[0]])

# look at regimes
for time_start, time_end, regime in zip(regimes.index[:-1], regimes.index[1:], regimes.values[:-1]):
    ax.axvspan(time_start,time_end, alpha=1, color=clr[regime])

# propagate last seen regime
ax.axvspan(time_end,"2022-12-31", alpha=1, color=clr[regimes[-1]])

ax.set_title(f"regimes for {strat_test.ticker} on the test set")
ax.set_ylabel("price")
plt.show()

# %%
""" Plot our predicted regimes on the validation set. """

regimes = strat_test.regimes_valid

fig, ax = plt.subplots(figsize=(16,8))
df_ts["2018-01-01":"2019-12-31"].plot(ax=ax, color='black')
clr = {0:'grey',1:'red'}

# assume default before we see any change
ax.axvspan('2018-01-01',regimes.index[0], alpha=1, color=clr[regimes[0]])

# look at the regimes
for time_start, time_end, regime in zip(regimes.index[:-1], regimes.index[1:], regimes.values[:-1]):
    ax.axvspan(time_start,time_end, alpha=1, color=clr[regime])

# propagate last seen regime
ax.axvspan(time_end,"2019-12-31", alpha=1, color=clr[regimes[-1]])

ax.set_title(f"regimes for {strat_test.ticker} on the validation set")
ax.set_ylabel("price")
plt.show()

# %% [markdown]
# # Comparing to SVM

# %%
""" Grid for hyperparameter tuning """

parameter_grid = {
    'theta': np.arange(0.01, stop=0.021, step=0.005),
    'DC_indicator': ['R', 'TMV', 'T'],
    'epsilon': [0.6, 0.65, 0.7, 0.75, 0.8],
    'model':['svm']
}

# %%
""" Pull data and run the grid search. We want to maximize profit. """

trading_day = {'equity':12, 'fx':12,'bond':9}
df_ts = get_data('^GSPC', start_date='2005-01-01', delta=trading_day['equity'])
cv3 = CustomCrossValidation(pipeline_class=Pipeline, parameter_grid=parameter_grid, verbose=True)
cv3.fit(data = df_ts, metric='profit', minimize=False)
# Out:
# [*********************100%***********************]  1 of 1 completed
# Iteration: 1 of 45: Parameters: {'DC_indicator': 'R', 'epsilon': 0.6, 'model': 'svm', 'theta': 0.01}
# Iteration: 1 of 45: Training complete.
# Iteration: 1 of 45: Loss: {'drawdown': 0.15476858537838412, 'profit': 0.05660923866428269, 'sharpe': 0.27909948638735205}
# Iteration: 2 of 45: Parameters: {'DC_indicator': 'R', 'epsilon': 0.6, 'model': 'svm', 'theta': 0.015}
# Iteration: 2 of 45: Training complete.
# Iteration: 2 of 45: Loss: {'drawdown': 0.16062405648755845, 'profit': 0.0879903043994934, 'sharpe': 0.3511267874220865}
# Iteration: 3 of 45: Parameters: {'DC_indicator': 'R', 'epsilon': 0.6, 'model': 'svm', 'theta': 0.019999999999999997}
# Iteration: 3 of 45: Training complete.
# Iteration: 3 of 45: Loss: {'drawdown': 0.17240205914205342, 'profit': 0.07111066491993512, 'sharpe': 0.28659436450957937}
# Iteration: 4 of 45: Parameters: {'DC_indicator': 'R', 'epsilon': 0.65, 'model': 'svm', 'theta': 0.01}
# Iteration: 4 of 45: Training complete.
# Iteration: 4 of 45: Loss: {'drawdown': 0.15476858537838412, 'profit': 0.05660923866428269, 'sharpe': 0.27909948638735205}
# Iteration: 5 of 45: Parameters: {'DC_indicator': 'R', 'epsilon': 0.65, 'model': 'svm', 'theta': 0.015}
# Iteration: 5 of 45: Training complete.
# Iteration: 5 of 45: Loss: {'drawdown': 0.16062405648755845, 'profit': 0.0879903043994934, 'sharpe': 0.3511267874220865}
# Iteration: 6 of 45: Parameters: {'DC_indicator': 'R', 'epsilon': 0.65, 'model': 'svm', 'theta': 0.019999999999999997}
# Iteration: 6 of 45: Training complete.
# Iteration: 6 of 45: Loss: {'drawdown': 0.17240205914205342, 'profit': 0.07111066491993512, 'sharpe': 0.28659436450957937}
# Iteration: 7 of 45: Parameters: {'DC_indicator': 'R', 'epsilon': 0.7, 'model': 'svm', 'theta': 0.01}
# Iteration: 7 of 45: Training complete.
# Iteration: 7 of 45: Loss: {'drawdown': 0.15476858537838412, 'profit': 0.05660923866428269, 'sharpe': 0.27909948638735205}
# Iteration: 8 of 45: Parameters: {'DC_indicator': 'R', 'epsilon': 0.7, 'model': 'svm', 'theta': 0.015}
# Iteration: 8 of 45: Training complete.
# Iteration: 8 of 45: Loss: {'drawdown': 0.16062405648755845, 'profit': 0.0879903043994934, 'sharpe': 0.3511267874220865}
# Iteration: 9 of 45: Parameters: {'DC_indicator': 'R', 'epsilon': 0.7, 'model': 'svm', 'theta': 0.019999999999999997}
# Iteration: 9 of 45: Training complete.
# Iteration: 9 of 45: Loss: {'drawdown': 0.17240205914205342, 'profit': 0.07111066491993512, 'sharpe': 0.28659436450957937}
# Iteration: 10 of 45: Parameters: {'DC_indicator': 'R', 'epsilon': 0.75, 'model': 'svm', 'theta': 0.01}
# Iteration: 10 of 45: Training complete.
# Iteration: 10 of 45: Loss: {'drawdown': 0.15476858537838412, 'profit': 0.05660923866428269, 'sharpe': 0.27909948638735205}
# Iteration: 11 of 45: Parameters: {'DC_indicator': 'R', 'epsilon': 0.75, 'model': 'svm', 'theta': 0.015}
# Iteration: 11 of 45: Training complete.
# Iteration: 11 of 45: Loss: {'drawdown': 0.16062405648755845, 'profit': 0.0879903043994934, 'sharpe': 0.3511267874220865}
# Iteration: 12 of 45: Parameters: {'DC_indicator': 'R', 'epsilon': 0.75, 'model': 'svm', 'theta': 0.019999999999999997}
# Iteration: 12 of 45: Training complete.
# Iteration: 12 of 45: Loss: {'drawdown': 0.17240205914205342, 'profit': 0.07111066491993512, 'sharpe': 0.28659436450957937}
# Iteration: 13 of 45: Parameters: {'DC_indicator': 'R', 'epsilon': 0.8, 'model': 'svm', 'theta': 0.01}
# Iteration: 13 of 45: Training complete.
# Iteration: 13 of 45: Loss: {'drawdown': 0.15476858537838412, 'profit': 0.05660923866428269, 'sharpe': 0.27909948638735205}
# Iteration: 14 of 45: Parameters: {'DC_indicator': 'R', 'epsilon': 0.8, 'model': 'svm', 'theta': 0.015}
# Iteration: 14 of 45: Training complete.
# Iteration: 14 of 45: Loss: {'drawdown': 0.16062405648755837, 'profit': 0.07934633089221577, 'sharpe': 0.32555902511402096}
# Iteration: 15 of 45: Parameters: {'DC_indicator': 'R', 'epsilon': 0.8, 'model': 'svm', 'theta': 0.019999999999999997}
# Iteration: 15 of 45: Training complete.
# Iteration: 15 of 45: Loss: {'drawdown': 0.17240205914205342, 'profit': 0.07111066491993512, 'sharpe': 0.28659436450957937}
# Iteration: 16 of 45: Parameters: {'DC_indicator': 'TMV', 'epsilon': 0.6, 'model': 'svm', 'theta': 0.01}
# Iteration: 16 of 45: Training complete.
# Iteration: 16 of 45: Loss: {'drawdown': 0.15476858537838412, 'profit': 0.05660923866428269, 'sharpe': 0.27909948638735205}
# Iteration: 17 of 45: Parameters: {'DC_indicator': 'TMV', 'epsilon': 0.6, 'model': 'svm', 'theta': 0.015}
# Iteration: 17 of 45: Training complete.
# Iteration: 17 of 45: Loss: {'drawdown': 0.16062405648755845, 'profit': 0.0879903043994934, 'sharpe': 0.3511267874220865}
# Iteration: 18 of 45: Parameters: {'DC_indicator': 'TMV', 'epsilon': 0.6, 'model': 'svm', 'theta': 0.019999999999999997}
# Iteration: 18 of 45: Training complete.
# Iteration: 18 of 45: Loss: {'drawdown': 0.17240205914205342, 'profit': 0.07111066491993512, 'sharpe': 0.28659436450957937}
# Iteration: 19 of 45: Parameters: {'DC_indicator': 'TMV', 'epsilon': 0.65, 'model': 'svm', 'theta': 0.01}
# Iteration: 19 of 45: Training complete.
# Iteration: 19 of 45: Loss: {'drawdown': 0.15476858537838412, 'profit': 0.05660923866428269, 'sharpe': 0.27909948638735205}
# Iteration: 20 of 45: Parameters: {'DC_indicator': 'TMV', 'epsilon': 0.65, 'model': 'svm', 'theta': 0.015}
# Iteration: 20 of 45: Training complete.
# Iteration: 20 of 45: Loss: {'drawdown': 0.16062405648755845, 'profit': 0.0879903043994934, 'sharpe': 0.3511267874220865}
# Iteration: 21 of 45: Parameters: {'DC_indicator': 'TMV', 'epsilon': 0.65, 'model': 'svm', 'theta': 0.019999999999999997}
# Iteration: 21 of 45: Training complete.
# Iteration: 21 of 45: Loss: {'drawdown': 0.17240205914205342, 'profit': 0.07111066491993512, 'sharpe': 0.28659436450957937}
# Iteration: 22 of 45: Parameters: {'DC_indicator': 'TMV', 'epsilon': 0.7, 'model': 'svm', 'theta': 0.01}
# Iteration: 22 of 45: Training complete.
# Iteration: 22 of 45: Loss: {'drawdown': 0.15476858537838412, 'profit': 0.05660923866428269, 'sharpe': 0.27909948638735205}
# Iteration: 23 of 45: Parameters: {'DC_indicator': 'TMV', 'epsilon': 0.7, 'model': 'svm', 'theta': 0.015}
# Iteration: 23 of 45: Training complete.
# Iteration: 23 of 45: Loss: {'drawdown': 0.16062405648755845, 'profit': 0.0879903043994934, 'sharpe': 0.3511267874220865}
# Iteration: 24 of 45: Parameters: {'DC_indicator': 'TMV', 'epsilon': 0.7, 'model': 'svm', 'theta': 0.019999999999999997}
# Iteration: 24 of 45: Training complete.
# Iteration: 24 of 45: Loss: {'drawdown': 0.17240205914205342, 'profit': 0.07111066491993512, 'sharpe': 0.28659436450957937}
# Iteration: 25 of 45: Parameters: {'DC_indicator': 'TMV', 'epsilon': 0.75, 'model': 'svm', 'theta': 0.01}
# Iteration: 25 of 45: Training complete.
# Iteration: 25 of 45: Loss: {'drawdown': 0.15476858537838412, 'profit': 0.05660923866428269, 'sharpe': 0.27909948638735205}
# Iteration: 26 of 45: Parameters: {'DC_indicator': 'TMV', 'epsilon': 0.75, 'model': 'svm', 'theta': 0.015}
# Iteration: 26 of 45: Training complete.
# Iteration: 26 of 45: Loss: {'drawdown': 0.16062405648755845, 'profit': 0.0879903043994934, 'sharpe': 0.3511267874220865}
# Iteration: 27 of 45: Parameters: {'DC_indicator': 'TMV', 'epsilon': 0.75, 'model': 'svm', 'theta': 0.019999999999999997}
# Iteration: 27 of 45: Training complete.
# Iteration: 27 of 45: Loss: {'drawdown': 0.17240205914205342, 'profit': 0.07111066491993512, 'sharpe': 0.28659436450957937}
# Iteration: 28 of 45: Parameters: {'DC_indicator': 'TMV', 'epsilon': 0.8, 'model': 'svm', 'theta': 0.01}
# Iteration: 28 of 45: Training complete.
# Iteration: 28 of 45: Loss: {'drawdown': 0.15476858537838412, 'profit': 0.05660923866428269, 'sharpe': 0.27909948638735205}
# Iteration: 29 of 45: Parameters: {'DC_indicator': 'TMV', 'epsilon': 0.8, 'model': 'svm', 'theta': 0.015}
# Iteration: 29 of 45: Training complete.
# Iteration: 29 of 45: Loss: {'drawdown': 0.16062405648755845, 'profit': 0.0879903043994934, 'sharpe': 0.3511267874220865}
# Iteration: 30 of 45: Parameters: {'DC_indicator': 'TMV', 'epsilon': 0.8, 'model': 'svm', 'theta': 0.019999999999999997}
# Iteration: 30 of 45: Training complete.
# Iteration: 30 of 45: Loss: {'drawdown': 0.17240205914205342, 'profit': 0.07111066491993512, 'sharpe': 0.28659436450957937}
# Iteration: 31 of 45: Parameters: {'DC_indicator': 'T', 'epsilon': 0.6, 'model': 'svm', 'theta': 0.01}
# Iteration: 31 of 45: Training complete.
# Iteration: 31 of 45: Loss: {'drawdown': 0.14971796958846756, 'profit': 0.0806240234970681, 'sharpe': 0.29264327205742896}
# Iteration: 32 of 45: Parameters: {'DC_indicator': 'T', 'epsilon': 0.6, 'model': 'svm', 'theta': 0.015}
# Iteration: 32 of 45: Training complete.
# Iteration: 32 of 45: Loss: {'drawdown': 0.1513805698976234, 'profit': 0.2077269652686724, 'sharpe': 0.5484074729823524}
# Iteration: 33 of 45: Parameters: {'DC_indicator': 'T', 'epsilon': 0.6, 'model': 'svm', 'theta': 0.019999999999999997}
# Iteration: 33 of 45: Training complete.
# Iteration: 33 of 45: Loss: {'drawdown': 0.173192787639177, 'profit': 0.21010499133694815, 'sharpe': 0.495565497339407}
# Iteration: 34 of 45: Parameters: {'DC_indicator': 'T', 'epsilon': 0.65, 'model': 'svm', 'theta': 0.01}
# Iteration: 34 of 45: Training complete.
# Iteration: 34 of 45: Loss: {'drawdown': 0.14971796958846756, 'profit': 0.0806240234970681, 'sharpe': 0.29264327205742896}
# Iteration: 35 of 45: Parameters: {'DC_indicator': 'T', 'epsilon': 0.65, 'model': 'svm', 'theta': 0.015}
# Iteration: 35 of 45: Training complete.
# Iteration: 35 of 45: Loss: {'drawdown': 0.1513805698976234, 'profit': 0.2077269652686724, 'sharpe': 0.5484074729823524}
# Iteration: 36 of 45: Parameters: {'DC_indicator': 'T', 'epsilon': 0.65, 'model': 'svm', 'theta': 0.019999999999999997}
# Iteration: 36 of 45: Training complete.
# Iteration: 36 of 45: Loss: {'drawdown': 0.173192787639177, 'profit': 0.21010499133694815, 'sharpe': 0.495565497339407}
# Iteration: 37 of 45: Parameters: {'DC_indicator': 'T', 'epsilon': 0.7, 'model': 'svm', 'theta': 0.01}
# Iteration: 37 of 45: Training complete.
# Iteration: 37 of 45: Loss: {'drawdown': 0.14971796958846756, 'profit': 0.0806240234970681, 'sharpe': 0.29264327205742896}
# Iteration: 38 of 45: Parameters: {'DC_indicator': 'T', 'epsilon': 0.7, 'model': 'svm', 'theta': 0.015}
# Iteration: 38 of 45: Training complete.
# Iteration: 38 of 45: Loss: {'drawdown': 0.1513805698976234, 'profit': 0.2077269652686724, 'sharpe': 0.5484074729823524}
# Iteration: 39 of 45: Parameters: {'DC_indicator': 'T', 'epsilon': 0.7, 'model': 'svm', 'theta': 0.019999999999999997}
# Iteration: 39 of 45: Training complete.
# Iteration: 39 of 45: Loss: {'drawdown': 0.1731927876391769, 'profit': 0.18797419995285325, 'sharpe': 0.4602792463338078}
# Iteration: 40 of 45: Parameters: {'DC_indicator': 'T', 'epsilon': 0.75, 'model': 'svm', 'theta': 0.01}
# Iteration: 40 of 45: Training complete.
# Iteration: 40 of 45: Loss: {'drawdown': 0.14971796958846756, 'profit': 0.0806240234970681, 'sharpe': 0.29264327205742896}
# Iteration: 41 of 45: Parameters: {'DC_indicator': 'T', 'epsilon': 0.75, 'model': 'svm', 'theta': 0.015}
# Iteration: 41 of 45: Training complete.
# Iteration: 41 of 45: Loss: {'drawdown': 0.151380569897623, 'profit': 0.20477916728119117, 'sharpe': 0.5091128647012347}
# Iteration: 42 of 45: Parameters: {'DC_indicator': 'T', 'epsilon': 0.75, 'model': 'svm', 'theta': 0.019999999999999997}
# Iteration: 42 of 45: Training complete.
# Iteration: 42 of 45: Loss: {'drawdown': 0.1731927876391769, 'profit': 0.18797419995285325, 'sharpe': 0.4602792463338078}
# Iteration: 43 of 45: Parameters: {'DC_indicator': 'T', 'epsilon': 0.8, 'model': 'svm', 'theta': 0.01}
# Iteration: 43 of 45: Training complete.
# Iteration: 43 of 45: Loss: {'drawdown': 0.14971796958846756, 'profit': 0.0806240234970681, 'sharpe': 0.29264327205742896}
# Iteration: 44 of 45: Parameters: {'DC_indicator': 'T', 'epsilon': 0.8, 'model': 'svm', 'theta': 0.015}
# Iteration: 44 of 45: Training complete.
# Iteration: 44 of 45: Loss: {'drawdown': 0.151380569897623, 'profit': 0.20477916728119117, 'sharpe': 0.5091128647012347}
# Iteration: 45 of 45: Parameters: {'DC_indicator': 'T', 'epsilon': 0.8, 'model': 'svm', 'theta': 0.019999999999999997}
# Iteration: 45 of 45: Training complete.
# Iteration: 45 of 45: Loss: {'drawdown': 0.17319278763917664, 'profit': 0.10536910824312051, 'sharpe': 0.324324735625209}

# %%
""" Optimal parameters and optimal value of the loss function. """

cv3.get_optimal_loss()
# Out:
# {'drawdown': 0.173192787639177,
#  'profit': 0.21010499133694815,
#  'sharpe': 0.495565497339407,
#  'parameters': {'DC_indicator': 'T',
#   'epsilon': 0.6,
#   'model': 'svm',
#   'theta': 0.019999999999999997}}

# %%
""" Fit the model with the optimal parameters found. """

regime_trade = Pipeline(df_ts= df_ts, **cv3.get_optimal_parameters())
regime_trade.fit(verbose = True)
# Out:
# Total duration of time: 396662400.0
# Total duration spent in Regime 1: 319291200.0
# Proportion of time spent in Regime 1: 0.8049444565454149
# Flipping labels between regimes.

# %%
""" Confirm that the trading metrics match. """
regime_trade.trading_metrics
# Out:
# {'drawdown': 0.173192787639177,
#  'profit': 0.21010499133694815,
#  'sharpe': 0.495565497339407}

# %%
""" Fit the same model for the control trading strategy."""

control = Pipeline(df_ts= df_ts, strat='control', **cv3.get_optimal_parameters())
control.fit(plot=False, verbose = True)
# Out:
# Total duration of time: 396662400.0
# Total duration spent in Regime 1: 319291200.0
# Proportion of time spent in Regime 1: 0.8049444565454149
# Flipping labels between regimes.

# %%
""" Confirm that there is an improvement when we use the regimes. """

control.trading_metrics
# Out:
# {'drawdown': 0.197107948275105,
#  'profit': 0.05202371492608826,
#  'sharpe': 0.23050795640032237}

# %%
""" Run the control strategy on test data. """
strat_test = Pipeline(df_ts= df_ts, to_test = True, strat='control', **cv3.get_optimal_parameters())
strat_test.fit(verbose = True)
strat_test.trading_metrics_test
# Out:
# Total duration of time: 396662400.0
# Total duration spent in Regime 1: 319291200.0
# Proportion of time spent in Regime 1: 0.8049444565454149
# Flipping labels between regimes.
# {'drawdown': 0.2701506503824544,
#  'profit': 0.40691312858269235,
#  'sharpe': 0.46022959091991317}

# %%
""" Run the control2 strategy on test data. """
strat_test = Pipeline(df_ts= df_ts, to_test = True, strat='control2', **cv3.get_optimal_parameters())
strat_test.fit(verbose = True)
strat_test.trading_metrics_test
# Out:
# Total duration of time: 396662400.0
# Total duration spent in Regime 1: 319291200.0
# Proportion of time spent in Regime 1: 0.8049444565454149
# Flipping labels between regimes.
# {'drawdown': 0.25873230856297735,
#  'profit': 0.5019380257164072,
#  'sharpe': 0.6115277904174444}

# %%
""" Run the strategy on test data. """
strat_test = Pipeline(df_ts= df_ts, to_test = True, **cv3.get_optimal_parameters())
strat_test.fit(verbose = True)
strat_test.trading_metrics_test
# Out:
# Total duration of time: 396662400.0
# Total duration spent in Regime 1: 319291200.0
# Proportion of time spent in Regime 1: 0.8049444565454149
# Flipping labels between regimes.
# {'drawdown': 0.21378587832646642,
#  'profit': 0.7527669340261292,
#  'sharpe': 0.752857105770566}

# %%
""" If you want to get the results in Latex """
# print(cv3.get_results_in_latex(
#     loss_columns=['profit', 'drawdown', 'sharpe'],
#     parameter_columns=['theta', 'epsilon', 'DC_indicator'],
#     caption='SVM Cross-Validation Results'))
# Out:
# ' If you want to get the results in Latex '

# %%
""" Plot our predicted regimes on the test set. """

regimes = strat_test.regimes_test

fig, ax = plt.subplots(figsize=(16,8))
df_ts["2020-01-01":].plot(ax=ax, color='black')
clr = {0:'grey',1:'red',2:'green'}

# assume default before we see any change
ax.axvspan('2020-01-01',regimes.index[0], alpha=1, color=clr[regimes[0]])

# look at regimes
for time_start, time_end, regime in zip(regimes.index[:-1], regimes.index[1:], regimes.values[:-1]):
    ax.axvspan(time_start,time_end, alpha=1, color=clr[regime])

# propagate last seen regime
ax.axvspan(time_end,"2022-12-31", alpha=1, color=clr[regimes[-1]])

ax.set_title(f"regimes for {strat_test.ticker} on the test set")
ax.set_ylabel("price")
plt.show()

# %%
""" Plot our predicted regimes on the validation set. """

regimes = strat_test.regimes_valid

fig, ax = plt.subplots(figsize=(16,8))
df_ts["2018-01-01":"2019-12-31"].plot(ax=ax, color='black')
clr = {0:'grey',1:'red'}

# assume default before we see any change
ax.axvspan('2018-01-01',regimes.index[0], alpha=1, color=clr[regimes[0]])

# look at the regimes
for time_start, time_end, regime in zip(regimes.index[:-1], regimes.index[1:], regimes.values[:-1]):
    ax.axvspan(time_start,time_end, alpha=1, color=clr[regime])

# propagate last seen regime
ax.axvspan(time_end,"2019-12-31", alpha=1, color=clr[regimes[-1]])

ax.set_title(f"regimes for {strat_test.ticker} on the validation set")
ax.set_ylabel("price")
plt.show()

# %% [markdown]
# ## Distribution of DCC indicator

# %%
model = Pipeline(df_ts= df_ts, **cv.get_optimal_parameters())
model.fit()

# %%
fig,ax = plt.subplots(figsize=(8,5))
model.R['train'].plot.hist(bins=20,ax=ax)
ax.set_title(f"Histogram for R on training data with a threshold of {cv.get_optimal_parameters()['theta']}")
ax.set_xlabel("R")
plt.show()

# %% [markdown]
# ## Further analysis of SVM and Logistic Regression

# %%
""" Logistic Regression """
lr = Pipeline(df_ts= df_ts, to_test = True, **cv2.get_optimal_parameters())
lr.fit(verbose = True)
lr.trading_metrics_test
# Out:
# Total duration of time: 396662400.0
# Total duration spent in Regime 1: 319291200.0
# Proportion of time spent in Regime 1: 0.8049444565454149
# Flipping labels between regimes.
# {'drawdown': 0.21378587832646642,
#  'profit': 0.7527669340261292,
#  'sharpe': 0.752857105770566}

# %%
""" Checking linear separability for Logistic Regression on Test """
fig,ax = plt.subplots(figsize=(10,5))
sns.scatterplot(data=lr.T['test'], c=np.where(lr.regimes_test==1, 'red','gray'))
plt.hlines(np.max(lr.T['test'][lr.regimes_test==1]),xmin=lr.T['test'].index[0],xmax=lr.T['test'].index[-1], linestyles='dashed')
gray_path = mpatches.Patch(color='gray', label='regime 0')
red_patch = mpatches.Patch(color='red', label='regime 1')
plt.legend(handles=[gray_path, red_patch])
ax.set_ylabel('T')
ax.set_xlabel('Date')
ax.set_title('Logistic Regression')
None

# %%
""" SVM """
sv = Pipeline(df_ts= df_ts, to_test = True, **cv3.get_optimal_parameters())
sv.fit(verbose = True)
sv.trading_metrics_test
# Out:
# Total duration of time: 396662400.0
# Total duration spent in Regime 1: 319291200.0
# Proportion of time spent in Regime 1: 0.8049444565454149
# Flipping labels between regimes.
# {'drawdown': 0.21378587832646642,
#  'profit': 0.7527669340261292,
#  'sharpe': 0.752857105770566}

# %%
""" Checking linear separability for SVM Predictions on Validation """
fig,ax = plt.subplots(figsize=(10,5))
sns.scatterplot(data=sv.T['test'], c=np.where(sv.regimes_test==1, 'red','gray'))
plt.hlines(np.max(sv.T['test'][sv.regimes_test==1]),xmin=sv.T['test'].index[0],xmax=sv.T['test'].index[-1], linestyles='dashed')
gray_path = mpatches.Patch(color='gray', label='regime 0')
red_patch = mpatches.Patch(color='red', label='regime 1')
plt.legend(handles=[gray_path, red_patch])
ax.set_ylabel('T')
ax.set_xlabel('Date')
ax.set_title('SVM')
None

# %%
""" naive Bayes """
nb = Pipeline(df_ts= df_ts, to_test = True, **cv.get_optimal_parameters())
nb.fit(verbose = True)
nb.trading_metrics_test
# Out:
# Total duration of time: 407764800.0
# Total duration spent in Regime 0: 162172800.0
# Proportion of time spent in Regime 0: 0.3977116219938553
# Flipping labels between regimes.
# {'drawdown': 0.25057140523989796,
#  'profit': 1.0823749162355516,
#  'sharpe': 1.210407488924396}

# %%
""" Checking linear separability for naive Bayes Predictions on Validation """
fig,ax = plt.subplots(figsize=(10,5))
sns.scatterplot(data=nb.R['test'], c=np.where(nb.regimes_test==1, 'red','gray'))
plt.hlines(np.max(nb.R['test'][nb.regimes_test==1]),xmin=nb.R['test'].index[0],xmax=nb.R['test'].index[-1], linestyles='dashed')
gray_path = mpatches.Patch(color='gray', label='regime 0')
red_patch = mpatches.Patch(color='red', label='regime 1')
plt.legend(handles=[gray_path, red_patch])
ax.set_ylabel('R')
ax.set_xlabel('Date')
ax.set_title('naive Bayes')
None

# %%
fig,ax = plt.subplots(figsize=(10,6))
nb.R['train'][nb.regimes == 1].plot.hist(ax=ax,alpha=0.8,color='red',label='Regime 1')
nb.R['train'][nb.regimes == 0].plot.hist(ax=ax,alpha=0.8,color='grey', label='Regime 0')
ax.legend()
ax.set_xlabel("DC Indicator R")
plt.show()

# %%
fig,ax = plt.subplots(figsize=(10,6))
lr.T['train'][lr.regimes == 1].plot.hist(ax=ax, bins= np.arange(lr.T['train'].min(),lr.T['train'].max(),12),alpha=0.8,color='red',label='Regime 1')
lr.T['train'][lr.regimes == 0].plot.hist(ax=ax, bins= np.arange(lr.T['train'].min(),lr.T['train'].max(),12),alpha=0.8,color='gray', label='Regime 0')
ax.legend()
ax.set_xlabel("DC Indicator T")
plt.show()
